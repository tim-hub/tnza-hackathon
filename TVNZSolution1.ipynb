# %%
import pandas as pd
from textblob import TextBlob
import indicoio

# %%
indicoio.config.api_key = 'ca64f795a2d673f848ba9c88f6c88c86'

# %% [markdown]
# # Processing all videos we have

# %%
shows = pd.read_csv("./DataSample.csv",  index_col=0)
# shows.set_index("id")

# %%
shows
# Out:
#                     title                                                url  \
# id
# 1   United States of Tara  https://www.tvnz.co.nz/shows/united-states-of-...
# 2      American Housewife    https://www.tvnz.co.nz/shows/american-housewife
# 3           2 Broke Girls         https://www.tvnz.co.nz/shows/2-broke-girls
# 4           Queer As Folk         https://www.tvnz.co.nz/shows/queer-as-folk
# 5               Bite Club             https://www.tvnz.co.nz/shows/bite-club
# 6               Abandoned             https://www.tvnz.co.nz/shows/abandoned
# 7           Baby Geniuses         https://www.tvnz.co.nz/shows/baby-geniuses
# 8                     AFL                   https://www.tvnz.co.nz/shows/afl
# 9   MasterChef Australia   https://www.tvnz.co.nz/shows/masterchef-australia
# 10       Apple Tree House      https://www.tvnz.co.nz/shows/apple-tree-house
# 11            Animanimals           https://www.tvnz.co.nz/shows/animanimals
# 12   A place to remember    https://www.tvnz.co.nz/shows/a-place-to-remember
# 13   Watch a plastic Tide        https://www.tvnz.co.nz/shows/a-plastic-tide
# 14                  20/20                 https://www.tvnz.co.nz/shows/20-20
# 15                Friends               https://www.tvnz.co.nz/shows/friends
# 16         Life in Pieces        https://www.tvnz.co.nz/shows/life-in-pieces
#
#                                           description        genre1  \
# id
# 1   Tara, a suburban wife and mother, suffers from...        Comedy
# 2   Katie Mixon is many things, a housewife is jus...        Comedy
# 3   They're faking it until they make it! Max and ...        Comedy
# 4   Follow three gay men living in Manchester, as ...  Full Seasons
# 5   After surviving a shark attack, Zoe and Dan me...     Adventure
# 6   119 days adrift, but found on Great Barrier Is...     Adventure
# 7   Super-intelligent babies are held captive by s...          Kids
# 8   Get up with the play and never miss a moment o...        sports
# 9   MasterChef Australia is back for its 10th seas...          food
# 10  Mali's an ordinary boy, who moves into an extr...          Kids
# 11               Join the wacky world of Animanimals!          Kids
# 12  What happens to Christchurch? Follow the rebui...  documentary
# 13  More than 8 million tonnes of plastic end up i...  documentary
# 14  Keep up to date with the best of international...         local
# 15  Make a date, your old friends are calling. The...        Comedy
# 16  A smart, relatable and laugh-out-loud comedy a...        Comedy
#
#              genre2
# id
# 1     Drama & Soaps
# 2            TVNZ 2
# 3      Full Seasons
# 4            TVNZ 2
# 5     Drama & Soaps
# 6             Movie
# 7             Movie
# 8            series
# 9           reality
# 10       pre-school
# 11       pre-school
# 12          factual
# 13          factual
# 14  current affairs
# 15     Full Seasons
# 16           TVNZ 2

# %% [markdown]
# # Processing videos' data

# %%
descriptions=list(shows['description'].values)

# %%
def get_emotion_attributes(descriptions):
    return indicoio.sentiment(descriptions)
emotions= get_emotion_attributes(descriptions)
shows["Emotion"]=pd.Series(emotions).values

# %%
def get_subjectivity_textbloc(descs):
    return list(map(lambda a: TextBlob(a).sentiment.subjectivity, descs))
subjectivities= get_subjectivity_textbloc(descriptions)
shows["Subjectivity"]= pd.Series(subjectivities).values

# %%
shows
# Out:
#                     title                                                url  \
# id
# 1   United States of Tara  https://www.tvnz.co.nz/shows/united-states-of-...
# 2      American Housewife    https://www.tvnz.co.nz/shows/american-housewife
# 3           2 Broke Girls         https://www.tvnz.co.nz/shows/2-broke-girls
# 4           Queer As Folk         https://www.tvnz.co.nz/shows/queer-as-folk
# 5               Bite Club             https://www.tvnz.co.nz/shows/bite-club
# 6               Abandoned             https://www.tvnz.co.nz/shows/abandoned
# 7           Baby Geniuses         https://www.tvnz.co.nz/shows/baby-geniuses
# 8                     AFL                   https://www.tvnz.co.nz/shows/afl
# 9   MasterChef Australia   https://www.tvnz.co.nz/shows/masterchef-australia
# 10       Apple Tree House      https://www.tvnz.co.nz/shows/apple-tree-house
# 11            Animanimals           https://www.tvnz.co.nz/shows/animanimals
# 12   A place to remember    https://www.tvnz.co.nz/shows/a-place-to-remember
# 13   Watch a plastic Tide        https://www.tvnz.co.nz/shows/a-plastic-tide
# 14                  20/20                 https://www.tvnz.co.nz/shows/20-20
# 15                Friends               https://www.tvnz.co.nz/shows/friends
# 16         Life in Pieces        https://www.tvnz.co.nz/shows/life-in-pieces
#
#                                           description        genre1  \
# id
# 1   Tara, a suburban wife and mother, suffers from...        Comedy
# 2   Katie Mixon is many things, a housewife is jus...        Comedy
# 3   They're faking it until they make it! Max and ...        Comedy
# 4   Follow three gay men living in Manchester, as ...  Full Seasons
# 5   After surviving a shark attack, Zoe and Dan me...     Adventure
# 6   119 days adrift, but found on Great Barrier Is...     Adventure
# 7   Super-intelligent babies are held captive by s...          Kids
# 8   Get up with the play and never miss a moment o...        sports
# 9   MasterChef Australia is back for its 10th seas...          food
# 10  Mali's an ordinary boy, who moves into an extr...          Kids
# 11               Join the wacky world of Animanimals!          Kids
# 12  What happens to Christchurch? Follow the rebui...  documentary
# 13  More than 8 million tonnes of plastic end up i...  documentary
# 14  Keep up to date with the best of international...         local
# 15  Make a date, your old friends are calling. The...        Comedy
# 16  A smart, relatable and laugh-out-loud comedy a...        Comedy
#
#              genre2   Emotion  Subjectivity
# id
# 1     Drama & Soaps  0.809798      0.425000
# 2            TVNZ 2  0.875896      0.716667
# 3      Full Seasons  0.380198      0.000000
# 4            TVNZ 2  0.771434      0.583333
# 5     Drama & Soaps  0.999596      0.507386
# 6             Movie  0.981692      0.783333
# 7             Movie  0.693993      0.600000
# 8            series  0.982789      0.300000
# 9           reality  0.990398      0.000000
# 10       pre-school  0.857841      0.390909
# 11       pre-school  0.738057      1.000000
# 12          factual  0.913745      0.250000
# 13          factual  0.381231      0.250000
# 14  current affairs  0.978835      0.233333
# 15     Full Seasons  0.995257      0.558929
# 16           TVNZ 2  0.997955      0.821429

# %% [markdown]
# # Get recomandations through Genre and Emotion Attributes

# %%
def get_video(title):
    the_show = shows[(shows.title == title)]
    return the_show

# %%
def get_recommandations(title):
    the_show = get_video(title)
    the_genre1= the_show.genre1.values[0]
    the_genre2 = the_show.genre2.values[0]
    print(title+" is "+the_genre1 +" and " + the_genre2)
    
    
    return shows.loc[(shows.genre1 == the_genre1) |(shows.genre2 == the_genre2)]

# %%
get_recommandations("2 Broke Girls")
# Out:
# 2 Broke Girls is Comedy and Full Seasons
#                     title                                                url  \
# id
# 1   United States of Tara  https://www.tvnz.co.nz/shows/united-states-of-...
# 2      American Housewife    https://www.tvnz.co.nz/shows/american-housewife
# 3           2 Broke Girls         https://www.tvnz.co.nz/shows/2-broke-girls
# 15                Friends               https://www.tvnz.co.nz/shows/friends
# 16         Life in Pieces        https://www.tvnz.co.nz/shows/life-in-pieces
#
#                                           description  genre1         genre2  \
# id
# 1   Tara, a suburban wife and mother, suffers from...  Comedy  Drama & Soaps
# 2   Katie Mixon is many things, a housewife is jus...  Comedy         TVNZ 2
# 3   They're faking it until they make it! Max and ...  Comedy   Full Seasons
# 15  Make a date, your old friends are calling. The...  Comedy   Full Seasons
# 16  A smart, relatable and laugh-out-loud comedy a...  Comedy         TVNZ 2
#
#      Emotion  Subjectivity
# id
# 1   0.809798      0.425000
# 2   0.875896      0.716667
# 3   0.380198      0.000000
# 15  0.995257      0.558929
# 16  0.997955      0.821429

# %% [markdown]
# # Random functions based on user history

# %%
#  user watching history
# 2, 3, 5 in fact
# user watched 2 comedy and 1 adventure
history_watched = [1,2,4 ]

# %%
def get_genre_watched_most(watched):
    df_watched= shows.iloc[watched]
#     the genre watched most by user
    the_genre = df_watched.genre1.mode().values[0]
#     the all videos on website data set 
#     shuffle them 
    the_shows= shows.loc[(shows.genre1 == the_genre) |(shows.genre2 == the_genre)].sample(frac=1)
#     and pick top 3 as results
    return the_shows.head(1)
    
get_genre_watched_most(history_watched)
# Out:
#                  title                                              url  \
# id
# 2   American Housewife  https://www.tvnz.co.nz/shows/american-housewife
#
#                                           description  genre1  genre2  \
# id
# 2   Katie Mixon is many things, a housewife is jus...  Comedy  TVNZ 2
#
#      Emotion  Subjectivity
# id
# 2   0.875896      0.716667
